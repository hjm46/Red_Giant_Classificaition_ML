# %% [markdown]
# # META DATA EXPLORATORY DATA ANALYSIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#                                   FILE           APOGEE_ID TELESCOPE  \
# 0  apStar-dr17-2M00000002+7417074.fits  2M00000002+7417074    apo25m
# 1  apStar-dr17-2M00000317+5821383.fits  2M00000317+5821383    apo25m
# 2  apStar-dr17-2M00000546+6152107.fits  2M00000546+6152107    apo25m
# 3  apStar-dr17-2M00001962+6502429.fits  2M00001962+6502429    apo25m
# 4  apStar-dr17-2M00002012+5612368.fits  2M00002012+5612368    apo25m
#
#    LOCATION_ID   FIELD ALT_ID        RA        DEC        GLON       GLAT  \
# 0         5046  120+12   none  0.000103  74.285408  119.401807  11.767414
# 1         4424  116-04   none  0.013232  58.360649  116.219079  -3.839647
# 2         5045  116+00   none  0.022759  61.869644  116.918992  -0.401038
# 3         4591  117+01   none  0.081787  65.045258  117.571765   2.706919
# 4         4264   N7789   none  0.083874  56.210224  115.829107  -5.955029
#
#    ...  GAIAEDR3_PHOT_RP_MEAN_MAG  GAIAEDR3_DR2_RADIAL_VELOCITY  \
# ...

# %%
df.columns.tolist()
# Out:
# ['FILE',
#  'APOGEE_ID',
#  'TELESCOPE',
#  'LOCATION_ID',
#  'FIELD',
#  'ALT_ID',
#  'RA',
#  'DEC',
#  'GLON',
#  'GLAT',
#  'J',
#  'J_ERR',
#  'H',
#  'H_ERR',
#  'K',
#  'K_ERR',
#  'SRC_H',
#  'WASH_M',
#  'WASH_M_ERR',
#  'WASH_T2',
#  'WASH_T2_ERR',
#  'DDO51',
#  'DDO51_ERR',
#  'IRAC_3_6',
#  'IRAC_3_6_ERR',
#  'IRAC_4_5',
#  'IRAC_4_5_ERR',
#  'IRAC_5_8',
#  'IRAC_5_8_ERR',
#  'IRAC_8_0',
#  'IRAC_8_0_ERR',
#  'WISE_4_5',
#  'WISE_4_5_ERR',
#  'TARG_4_5',
#  'TARG_4_5_ERR',
#  'WASH_DDO51_GIANT_FLAG',
#  'WASH_DDO51_STAR_FLAG',
#  'TARG_PMRA',
#  'TARG_PMDEC',
#  'TARG_PM_SRC',
#  'AK_TARG',
#  'AK_TARG_METHOD',
#  'AK_WISE',
#  'SFD_EBV',
#  'APOGEE_TARGET1',
#  'APOGEE_TARGET2',
#  'APOGEE2_TARGET1',
#  'APOGEE2_TARGET2',
#  'APOGEE2_TARGET3',
#  'APOGEE2_TARGET4',
#  'TARGFLAGS',
#  'SURVEY',
#  'PROGRAMNAME',
#  'NINST',
#  'NVISITS',
#  'COMBTYPE',
#  'COMMISS',
#  'SNR',
#  'SNREV',
#  'STARFLAG',
#  'STARFLAGS',
#  'ANDFLAG',
#  'ANDFLAGS',
#  'VHELIO_AVG',
# ...

# %% [markdown]
# ### Graphs

# %%
sns.histplot(data=df["SNR"], bins=50)
plt.title("Signal to Noise Ratio Histogram with 50 Bins")
plt.xlabel("Signal to Noise Ratio")
plt.ylabel("Occurance Count")
# Out:
# Text(0, 0.5, 'Occurance Count')

# %%
sns.histplot(data=df["RV_TEFF"], bins=50)
plt.title("Effective Temperature Histogram with 50 Bins")
plt.xlabel("Effective Temperature [K]")
plt.ylabel("Occurance Counts")
# Out:
# Text(0, 0.5, 'Occurance Counts')

# %%
sns.histplot(data=df["RV_LOGG"], bins=50)
plt.title("Log Effective Surface Gravity Histogram with 50 Bins")
plt.xlabel("Log Effective Surface Gravity [log(m/s^2)]")
plt.ylabel("Occurance Counts")
# Out:
# Text(0, 0.5, 'Occurance Counts')

# %%
df2 = pd.read_csv("allstar_processed_fixed.csv")

# %% [markdown]
# ### Graphing data as HR Diagram

# %%
sns.histplot(
    data=df2, x="RV_TEFF", y="RV_LOGG", 
    bins=1500, pthresh=0.1, cmap="inferno", cbar=True,
    cbar_kws={'label': 'Number of Stars'}, vmax=50
)

plt.gca().invert_xaxis() 
plt.gca().invert_yaxis()

plt.xlabel('Effective Temperature [K]')
plt.ylabel('Surface Gravity [log(m/s^2)]')
plt.title('H-R Density Heatmap (All APOGEE Stars)')
plt.xlim(7000, 3600)
plt.ylim(5, 0.5)

plt.show()

# %%
sns.histplot(
    data=df, x="RV_TEFF", y="RV_LOGG", 
    bins=200, pthresh=0.1, cmap="inferno", cbar=True,
    cbar_kws={'label': 'Number of Stars'}, vmax=20
)

plt.gca().invert_xaxis() 
plt.gca().invert_yaxis()

plt.xlabel('Effective Temperature [K]')
plt.ylabel('Surface Gravity [log(m/s^2)]')
plt.title('H-R Density Heatmap (RBG)')

plt.show()

# %% [markdown]
# ### Differentiating between Red Giant and Red Clump stars
#
# Using logic from the Bovy Paper.
#
# 1.8 <= logg <= 0.0018 dex K^−1 Teff−Tref_eff ([Fe/H])+2.5,
#
# where
#
# Tref_eff ([Fe/H]) =−382.5K dex^−1 [Fe/H] + 4607K

# %%
# using shuffled data for training
df_shuffled = pd.read_csv("cleaned_data_shuffled.csv")

t_ref = -382.5 * df_shuffled['RV_FEH'] + 4607
delta_t = df_shuffled['RV_TEFF'] - t_ref
logg_upper_bound = (0.0018 * delta_t) + 2.5

rc_mask = df_shuffled["RV_LOGG"].between(1.8, logg_upper_bound)
df_shuffled["Stellar_type"] = np.where(rc_mask, "Red Clump", "Red Giant")

# %%
sns.scatterplot(
    data=df_shuffled, 
    x="RV_TEFF", 
    y="RV_LOGG", 
    hue="Stellar_type", 
    palette={"Red Clump": "#FFD700", "Red Giant": "#DC143C"},
    s=15, 
    alpha=0.6,
    edgecolor=None
)

plt.gca().invert_xaxis()
plt.gca().invert_yaxis()

plt.title('HR Diagram: Red Clump vs. Red Giant Branch')
plt.xlabel('Effective Temperature [K]')
plt.ylabel('Surface Gravity [log(m/s^2)]')
plt.legend(title='Stellar Classification', loc='upper left')

plt.show()
